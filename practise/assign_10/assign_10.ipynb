# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('Iris.csv')

# %%
df.head()
# Out:
#    Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm      Species
# 0   1            5.1           3.5            1.4           0.2  Iris-setosa
# 1   2            4.9           3.0            1.4           0.2  Iris-setosa
# 2   3            4.7           3.2            1.3           0.2  Iris-setosa
# 3   4            4.6           3.1            1.5           0.2  Iris-setosa
# 4   5            5.0           3.6            1.4           0.2  Iris-setosa

# %%
df.isnull().sum()
# Out:
# Id               0
# SepalLengthCm    0
# SepalWidthCm     0
# PetalLengthCm    0
# PetalWidthCm     0
# Species          0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id             150 non-null    int64
#  1   SepalLengthCm  150 non-null    float64
#  2   SepalWidthCm   150 non-null    float64
#  3   PetalLengthCm  150 non-null    float64
#  4   PetalWidthCm   150 non-null    float64
#  5   Species        150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
df.describe()
# Out:
#                Id  SepalLengthCm  SepalWidthCm  PetalLengthCm  PetalWidthCm
# count  150.000000     150.000000    150.000000     150.000000    150.000000
# mean    75.500000       5.843333      3.054000       3.758667      1.198667
# std     43.445368       0.828066      0.433594       1.764420      0.763161
# min      1.000000       4.300000      2.000000       1.000000      0.100000
# 25%     38.250000       5.100000      2.800000       1.600000      0.300000
# 50%     75.500000       5.800000      3.000000       4.350000      1.300000
# 75%    112.750000       6.400000      3.300000       5.100000      1.800000
# max    150.000000       7.900000      4.400000       6.900000      2.500000

# %%
df.dtypes
# Out:
# Id                 int64
# SepalLengthCm    float64
# SepalWidthCm     float64
# PetalLengthCm    float64
# PetalWidthCm     float64
# Species           object
# dtype: object

# %% [markdown]
# ### All features are numeric except Species which is nominal

# %% [markdown]
# ## Histogram for all features

# %%
plt.figure(figsize=(10,8))
sns.histplot(x='SepalLengthCm', hue='Species', data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(x='SepalWidthCm', hue='Species', data=df)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm', ylabel='Count'>

# %%
plt.figure(figsize=(10,8))
sns.histplot(x='PetalLengthCm', hue='Species', data=df)
# Out:
# <AxesSubplot:xlabel='PetalLengthCm', ylabel='Count'>

# %%
sns.histplot(x='Species', hue='Species', data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='Count'>

# %%
df.columns
# Out:
# Index(['Id', 'SepalLengthCm', 'SepalWidthCm', 'PetalLengthCm', 'PetalWidthCm',
#        'Species'],
#       dtype='object')

# %%
sns.boxplot(y='Species', x='SepalLengthCm', data=df)
# Out:
# <AxesSubplot:xlabel='SepalLengthCm', ylabel='Species'>

# %%
sns.boxplot(x='Species', y='PetalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='Species', ylabel='PetalWidthCm'>

# %%
df.plot(kind='box', subplots=True, layout=(4,4), fontsize=18,figsize=(22,22))
# Out:
# Id                  AxesSubplot(0.125,0.71587;0.168478x0.16413)
# SepalLengthCm    AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# SepalWidthCm     AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# PetalLengthCm    AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# PetalWidthCm       AxesSubplot(0.125,0.518913;0.168478x0.16413)
# dtype: object

# %%
sns.boxplot(x='SepalWidthCm', data=df)
# Out:
# <AxesSubplot:xlabel='SepalWidthCm'>

# %%
df.plot(kind='box', subplots=True, layout=(4,4), fontsize=18,figsize=(22,22))
# Out:
# Id                  AxesSubplot(0.125,0.71587;0.168478x0.16413)
# SepalLengthCm    AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# SepalWidthCm     AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# PetalLengthCm    AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# PetalWidthCm       AxesSubplot(0.125,0.518913;0.168478x0.16413)
# dtype: object

# %%
df.plot(kind='box', subplots=True, figsize=(22, 22), layout=(4,4))
# Out:
# Id                  AxesSubplot(0.125,0.71587;0.168478x0.16413)
# SepalLengthCm    AxesSubplot(0.327174,0.71587;0.168478x0.16413)
# SepalWidthCm     AxesSubplot(0.529348,0.71587;0.168478x0.16413)
# PetalLengthCm    AxesSubplot(0.731522,0.71587;0.168478x0.16413)
# PetalWidthCm       AxesSubplot(0.125,0.518913;0.168478x0.16413)
# dtype: object
