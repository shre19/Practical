# %% [markdown]
# # Assignment 9

# %% [markdown]
# # Importing the libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Preprocessing

# %%
df = pd.read_csv("/home/pict/Downloads/tested.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df["Age"].fillna(value=df["Age"].mean,inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age              0
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df.fillna('', inplace=True)

# %%
df.isnull().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Cabin          0
# Embarked       0
# dtype: int64

# %% [markdown]
# # 1.Box Plot

# %%
df1 = pd.read_csv("/home/pict/Downloads/tested.csv")
sns.boxplot(data = df1,x = "Age", y = "Sex")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.boxplot(data = df1,x = "Age", y = "Sex",hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# # 2.Bar Plot

# %%
df2 = pd.read_csv("/home/pict/Downloads/tested.csv")
sns.barplot(x = "Age",y = "Sex",data = df2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.barplot(x = "Age",y = "Sex",data = df2,hue = "Survived"Box plot:)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# # 3.Swarm Plot

# %%
sns.swarmplot(x = "Age",y = "Sex",data = df2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.swarmplot(x = "Age",y = "Sex",data = df2,hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# # 4.Violin Plot

# %%
sns.violinplot(x = "Age",y = "Sex",data = df2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.violinplot(x = "Age",y = "Sex",data = df2,hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %% [markdown]
# # 5.Strip Plot

# %%
sns.stripplot(x = "Age",y = "Sex",data = df2)
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>

# %%
sns.stripplot(x = "Age",y = "Sex",data = df2,hue = "Survived")
# Out:
# <AxesSubplot:xlabel='Age', ylabel='Sex'>
